# %%
# Use scikit-learn to grid search the batch size and epochs
import numpy
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
# Out:
# Using TensorFlow backend.

# %%
# Function to create model, required for KerasClassifier
def create_model(optimizer='adam'):
	# create model
	model = Sequential()
	model.add(Dense(12, input_dim=8, activation='relu'))
	model.add(Dense(1, activation='sigmoid'))
	# Compile model
	model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
	return model

# %%
# load dataset
dataset = numpy.loadtxt("./input/pima-indians-diabetes.csv", delimiter=",")

# %%
print len(dataset)
# Out:
# 768

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# create model
model = KerasClassifier(
    build_fn = create_model, 
    verbose = 0
)

grid = GridSearchCV(
    estimator = model, 
    param_grid = dict(
        epochs = [5, 10, 15],
        batch_size = [5, 10, 20],
        optimizer = ['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam']
    ), 
    n_jobs=1, 
    verbose=2
)

grid_result = grid.fit(X, Y)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 3 folds for each of 63 candidates, totalling 189 fits
# [CV] epochs=5, optimizer=SGD, batch_size=5 ...........................
# [CV] ............ epochs=5, optimizer=SGD, batch_size=5, total=   1.3s
# [CV] epochs=5, optimizer=SGD, batch_size=5 ...........................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [CV] ............ epochs=5, optimizer=SGD, batch_size=5, total=   0.9s
# [CV] epochs=5, optimizer=SGD, batch_size=5 ...........................
# [CV] ............ epochs=5, optimizer=SGD, batch_size=5, total=   1.0s
# [CV] epochs=5, optimizer=RMSprop, batch_size=5 .......................
# [CV] ........ epochs=5, optimizer=RMSprop, batch_size=5, total=   1.0s
# [CV] epochs=5, optimizer=RMSprop, batch_size=5 .......................
# [CV] ........ epochs=5, optimizer=RMSprop, batch_size=5, total=   1.0s
# [CV] epochs=5, optimizer=RMSprop, batch_size=5 .......................
# [CV] ........ epochs=5, optimizer=RMSprop, batch_size=5, total=   1.0s
# [CV] epochs=5, optimizer=Adagrad, batch_size=5 .......................
# [CV] ........ epochs=5, optimizer=Adagrad, batch_size=5, total=   1.0s
# [CV] epochs=5, optimizer=Adagrad, batch_size=5 .......................
# [CV] ........ epochs=5, optimizer=Adagrad, batch_size=5, total=   1.0s
# [CV] epochs=5, optimizer=Adagrad, batch_size=5 .......................
# [CV] ........ epochs=5, optimizer=Adagrad, batch_size=5, total=   1.0s
# [CV] epochs=5, optimizer=Adadelta, batch_size=5 ......................
# [CV] ....... epochs=5, optimizer=Adadelta, batch_size=5, total=   1.1s
# [CV] epochs=5, optimizer=Adadelta, batch_size=5 ......................
# [CV] ....... epochs=5, optimizer=Adadelta, batch_size=5, total=   1.1s
# [CV] epochs=5, optimizer=Adadelta, batch_size=5 ......................
# [CV] ....... epochs=5, optimizer=Adadelta, batch_size=5, total=   1.2s
# [CV] epochs=5, optimizer=Adam, batch_size=5 ..........................
# [CV] ........... epochs=5, optimizer=Adam, batch_size=5, total=   1.1s
# [CV] epochs=5, optimizer=Adam, batch_size=5 ..........................
# [CV] ........... epochs=5, optimizer=Adam, batch_size=5, total=   1.2s
# [CV] epochs=5, optimizer=Adam, batch_size=5 ..........................
# [CV] ........... epochs=5, optimizer=Adam, batch_size=5, total=   1.3s
# [CV] epochs=5, optimizer=Adamax, batch_size=5 ........................
# [CV] ......... epochs=5, optimizer=Adamax, batch_size=5, total=   1.1s
# [CV] epochs=5, optimizer=Adamax, batch_size=5 ........................
# [CV] ......... epochs=5, optimizer=Adamax, batch_size=5, total=   1.2s
# [CV] epochs=5, optimizer=Adamax, batch_size=5 ........................
# [CV] ......... epochs=5, optimizer=Adamax, batch_size=5, total=   1.2s
# [CV] epochs=5, optimizer=Nadam, batch_size=5 .........................
# [CV] .......... epochs=5, optimizer=Nadam, batch_size=5, total=   1.4s
# [CV] epochs=5, optimizer=Nadam, batch_size=5 .........................
# [CV] .......... epochs=5, optimizer=Nadam, batch_size=5, total=   1.5s
# [CV] epochs=5, optimizer=Nadam, batch_size=5 .........................
# [CV] .......... epochs=5, optimizer=Nadam, batch_size=5, total=   1.4s
# [CV] epochs=10, optimizer=SGD, batch_size=5 ..........................
# [CV] ........... epochs=10, optimizer=SGD, batch_size=5, total=   2.0s
# [CV] epochs=10, optimizer=SGD, batch_size=5 ..........................
# [CV] ........... epochs=10, optimizer=SGD, batch_size=5, total=   1.9s
# [CV] epochs=10, optimizer=SGD, batch_size=5 ..........................
# [CV] ........... epochs=10, optimizer=SGD, batch_size=5, total=   1.9s
# [CV] epochs=10, optimizer=RMSprop, batch_size=5 ......................
# [CV] ....... epochs=10, optimizer=RMSprop, batch_size=5, total=   2.1s
# [CV] epochs=10, optimizer=RMSprop, batch_size=5 ......................
# [CV] ....... epochs=10, optimizer=RMSprop, batch_size=5, total=   2.2s
# [CV] epochs=10, optimizer=RMSprop, batch_size=5 ......................
# [CV] ....... epochs=10, optimizer=RMSprop, batch_size=5, total=   2.2s
# [CV] epochs=10, optimizer=Adagrad, batch_size=5 ......................
# [CV] ....... epochs=10, optimizer=Adagrad, batch_size=5, total=   2.2s
# [CV] epochs=10, optimizer=Adagrad, batch_size=5 ......................
# [CV] ....... epochs=10, optimizer=Adagrad, batch_size=5, total=   2.2s
# [CV] epochs=10, optimizer=Adagrad, batch_size=5 ......................
# [CV] ....... epochs=10, optimizer=Adagrad, batch_size=5, total=   2.1s
# [CV] epochs=10, optimizer=Adadelta, batch_size=5 .....................
# [CV] ...... epochs=10, optimizer=Adadelta, batch_size=5, total=   2.4s
# [CV] epochs=10, optimizer=Adadelta, batch_size=5 .....................
# [CV] ...... epochs=10, optimizer=Adadelta, batch_size=5, total=   2.5s
# [CV] epochs=10, optimizer=Adadelta, batch_size=5 .....................
# [CV] ...... epochs=10, optimizer=Adadelta, batch_size=5, total=   2.5s
# [CV] epochs=10, optimizer=Adam, batch_size=5 .........................
# [CV] .......... epochs=10, optimizer=Adam, batch_size=5, total=   2.6s
# [CV] epochs=10, optimizer=Adam, batch_size=5 .........................
# [CV] .......... epochs=10, optimizer=Adam, batch_size=5, total=   2.4s
# [CV] epochs=10, optimizer=Adam, batch_size=5 .........................
# [CV] .......... epochs=10, optimizer=Adam, batch_size=5, total=   2.4s
# [CV] epochs=10, optimizer=Adamax, batch_size=5 .......................
# [CV] ........ epochs=10, optimizer=Adamax, batch_size=5, total=   2.4s
# [CV] epochs=10, optimizer=Adamax, batch_size=5 .......................
# [CV] ........ epochs=10, optimizer=Adamax, batch_size=5, total=   2.5s
# [CV] epochs=10, optimizer=Adamax, batch_size=5 .......................
# [CV] ........ epochs=10, optimizer=Adamax, batch_size=5, total=   2.6s
# [CV] epochs=10, optimizer=Nadam, batch_size=5 ........................
# [CV] ......... epochs=10, optimizer=Nadam, batch_size=5, total=   2.9s
# [CV] epochs=10, optimizer=Nadam, batch_size=5 ........................
# [CV] ......... epochs=10, optimizer=Nadam, batch_size=5, total=   2.9s
# [CV] epochs=10, optimizer=Nadam, batch_size=5 ........................
# [CV] ......... epochs=10, optimizer=Nadam, batch_size=5, total=   2.9s
# [CV] epochs=15, optimizer=SGD, batch_size=5 ..........................
# [CV] ........... epochs=15, optimizer=SGD, batch_size=5, total=   3.0s
# [CV] epochs=15, optimizer=SGD, batch_size=5 ..........................
# [CV] ........... epochs=15, optimizer=SGD, batch_size=5, total=   3.2s
# [CV] epochs=15, optimizer=SGD, batch_size=5 ..........................
# [CV] ........... epochs=15, optimizer=SGD, batch_size=5, total=   3.6s
# [CV] epochs=15, optimizer=RMSprop, batch_size=5 ......................
# [CV] ....... epochs=15, optimizer=RMSprop, batch_size=5, total=   5.6s
# [CV] epochs=15, optimizer=RMSprop, batch_size=5 ......................
# [CV] ....... epochs=15, optimizer=RMSprop, batch_size=5, total=   3.8s
# [CV] epochs=15, optimizer=RMSprop, batch_size=5 ......................
# [CV] ....... epochs=15, optimizer=RMSprop, batch_size=5, total=   4.4s
# [CV] epochs=15, optimizer=Adagrad, batch_size=5 ......................
# [CV] ....... epochs=15, optimizer=Adagrad, batch_size=5, total=   3.9s
# [CV] epochs=15, optimizer=Adagrad, batch_size=5 ......................
# [CV] ....... epochs=15, optimizer=Adagrad, batch_size=5, total=   4.0s
# [CV] epochs=15, optimizer=Adagrad, batch_size=5 ......................
# [CV] ....... epochs=15, optimizer=Adagrad, batch_size=5, total=   3.4s
# [CV] epochs=15, optimizer=Adadelta, batch_size=5 .....................
# [CV] ...... epochs=15, optimizer=Adadelta, batch_size=5, total=   3.7s
# [CV] epochs=15, optimizer=Adadelta, batch_size=5 .....................
# [CV] ...... epochs=15, optimizer=Adadelta, batch_size=5, total=   4.0s
# [CV] epochs=15, optimizer=Adadelta, batch_size=5 .....................
# [CV] ...... epochs=15, optimizer=Adadelta, batch_size=5, total=   4.0s
# [CV] epochs=15, optimizer=Adam, batch_size=5 .........................
# [CV] .......... epochs=15, optimizer=Adam, batch_size=5, total=   4.3s
# [CV] epochs=15, optimizer=Adam, batch_size=5 .........................
# [CV] .......... epochs=15, optimizer=Adam, batch_size=5, total=   4.0s
# [CV] epochs=15, optimizer=Adam, batch_size=5 .........................
# [CV] .......... epochs=15, optimizer=Adam, batch_size=5, total=   4.1s
# [CV] epochs=15, optimizer=Adamax, batch_size=5 .......................
# [CV] ........ epochs=15, optimizer=Adamax, batch_size=5, total=   4.0s
# [CV] epochs=15, optimizer=Adamax, batch_size=5 .......................
# [CV] ........ epochs=15, optimizer=Adamax, batch_size=5, total=   4.0s
# [CV] epochs=15, optimizer=Adamax, batch_size=5 .......................
# [CV] ........ epochs=15, optimizer=Adamax, batch_size=5, total=   3.9s
# [CV] epochs=15, optimizer=Nadam, batch_size=5 ........................
# [CV] ......... epochs=15, optimizer=Nadam, batch_size=5, total=   4.4s
# [CV] epochs=15, optimizer=Nadam, batch_size=5 ........................
# [CV] ......... epochs=15, optimizer=Nadam, batch_size=5, total=   4.2s
# [CV] epochs=15, optimizer=Nadam, batch_size=5 ........................
# [CV] ......... epochs=15, optimizer=Nadam, batch_size=5, total=   4.4s
# [CV] epochs=5, optimizer=SGD, batch_size=10 ..........................
# [CV] ........... epochs=5, optimizer=SGD, batch_size=10, total=   1.5s
# [CV] epochs=5, optimizer=SGD, batch_size=10 ..........................
# [CV] ........... epochs=5, optimizer=SGD, batch_size=10, total=   1.5s
# [CV] epochs=5, optimizer=SGD, batch_size=10 ..........................
# [CV] ........... epochs=5, optimizer=SGD, batch_size=10, total=   1.6s
# [CV] epochs=5, optimizer=RMSprop, batch_size=10 ......................
# [CV] ....... epochs=5, optimizer=RMSprop, batch_size=10, total=   1.6s
# [CV] epochs=5, optimizer=RMSprop, batch_size=10 ......................
# [CV] ....... epochs=5, optimizer=RMSprop, batch_size=10, total=   1.6s
# [CV] epochs=5, optimizer=RMSprop, batch_size=10 ......................
# [CV] ....... epochs=5, optimizer=RMSprop, batch_size=10, total=   2.0s
# [CV] epochs=5, optimizer=Adagrad, batch_size=10 ......................
# [CV] ....... epochs=5, optimizer=Adagrad, batch_size=10, total=   1.9s
# [CV] epochs=5, optimizer=Adagrad, batch_size=10 ......................
# [CV] ....... epochs=5, optimizer=Adagrad, batch_size=10, total=   1.8s
# [CV] epochs=5, optimizer=Adagrad, batch_size=10 ......................
# [CV] ....... epochs=5, optimizer=Adagrad, batch_size=10, total=   1.9s
# [CV] epochs=5, optimizer=Adadelta, batch_size=10 .....................
# [CV] ...... epochs=5, optimizer=Adadelta, batch_size=10, total=   1.9s
# [CV] epochs=5, optimizer=Adadelta, batch_size=10 .....................
# [CV] ...... epochs=5, optimizer=Adadelta, batch_size=10, total=   2.0s
# [CV] epochs=5, optimizer=Adadelta, batch_size=10 .....................
# [CV] ...... epochs=5, optimizer=Adadelta, batch_size=10, total=   2.0s
# [CV] epochs=5, optimizer=Adam, batch_size=10 .........................
# [CV] .......... epochs=5, optimizer=Adam, batch_size=10, total=   2.1s
# [CV] epochs=5, optimizer=Adam, batch_size=10 .........................
# [CV] .......... epochs=5, optimizer=Adam, batch_size=10, total=   1.9s
# [CV] epochs=5, optimizer=Adam, batch_size=10 .........................
# [CV] .......... epochs=5, optimizer=Adam, batch_size=10, total=   2.0s
# [CV] epochs=5, optimizer=Adamax, batch_size=10 .......................
# [CV] ........ epochs=5, optimizer=Adamax, batch_size=10, total=   1.9s
# [CV] epochs=5, optimizer=Adamax, batch_size=10 .......................
# [CV] ........ epochs=5, optimizer=Adamax, batch_size=10, total=   2.0s
# [CV] epochs=5, optimizer=Adamax, batch_size=10 .......................
# [CV] ........ epochs=5, optimizer=Adamax, batch_size=10, total=   2.1s
# [CV] epochs=5, optimizer=Nadam, batch_size=10 ........................
# [CV] ......... epochs=5, optimizer=Nadam, batch_size=10, total=   2.3s
# [CV] epochs=5, optimizer=Nadam, batch_size=10 ........................
# [CV] ......... epochs=5, optimizer=Nadam, batch_size=10, total=   2.1s
# [CV] epochs=5, optimizer=Nadam, batch_size=10 ........................
# [CV] ......... epochs=5, optimizer=Nadam, batch_size=10, total=   2.1s
# [CV] epochs=10, optimizer=SGD, batch_size=10 .........................
# [CV] .......... epochs=10, optimizer=SGD, batch_size=10, total=   2.3s
# [CV] epochs=10, optimizer=SGD, batch_size=10 .........................
# [CV] .......... epochs=10, optimizer=SGD, batch_size=10, total=   2.3s
# [CV] epochs=10, optimizer=SGD, batch_size=10 .........................
# [CV] .......... epochs=10, optimizer=SGD, batch_size=10, total=   2.7s
# [CV] epochs=10, optimizer=RMSprop, batch_size=10 .....................
# [CV] ...... epochs=10, optimizer=RMSprop, batch_size=10, total=   2.5s
# [CV] epochs=10, optimizer=RMSprop, batch_size=10 .....................
# [CV] ...... epochs=10, optimizer=RMSprop, batch_size=10, total=   2.4s
# [CV] epochs=10, optimizer=RMSprop, batch_size=10 .....................
# [CV] ...... epochs=10, optimizer=RMSprop, batch_size=10, total=   2.6s
# [CV] epochs=10, optimizer=Adagrad, batch_size=10 .....................
# [CV] ...... epochs=10, optimizer=Adagrad, batch_size=10, total=   2.5s
# [CV] epochs=10, optimizer=Adagrad, batch_size=10 .....................
# [CV] ...... epochs=10, optimizer=Adagrad, batch_size=10, total=   2.5s
# [CV] epochs=10, optimizer=Adagrad, batch_size=10 .....................
# [CV] ...... epochs=10, optimizer=Adagrad, batch_size=10, total=   2.5s
# [CV] epochs=10, optimizer=Adadelta, batch_size=10 ....................
# [CV] ..... epochs=10, optimizer=Adadelta, batch_size=10, total=   3.3s
# [CV] epochs=10, optimizer=Adadelta, batch_size=10 ....................
# [CV] ..... epochs=10, optimizer=Adadelta, batch_size=10, total=   2.9s
# [CV] epochs=10, optimizer=Adadelta, batch_size=10 ....................
# [CV] ..... epochs=10, optimizer=Adadelta, batch_size=10, total=   2.9s
# [CV] epochs=10, optimizer=Adam, batch_size=10 ........................
# [CV] ......... epochs=10, optimizer=Adam, batch_size=10, total=   2.9s
# [CV] epochs=10, optimizer=Adam, batch_size=10 ........................
# [CV] ......... epochs=10, optimizer=Adam, batch_size=10, total=   2.8s
# [CV] epochs=10, optimizer=Adam, batch_size=10 ........................
# [CV] ......... epochs=10, optimizer=Adam, batch_size=10, total=   2.8s
# [CV] epochs=10, optimizer=Adamax, batch_size=10 ......................
# [CV] ....... epochs=10, optimizer=Adamax, batch_size=10, total=   2.7s
# [CV] epochs=10, optimizer=Adamax, batch_size=10 ......................
# [CV] ....... epochs=10, optimizer=Adamax, batch_size=10, total=   2.9s
# [CV] epochs=10, optimizer=Adamax, batch_size=10 ......................
# [CV] ....... epochs=10, optimizer=Adamax, batch_size=10, total=   2.8s
# [CV] epochs=10, optimizer=Nadam, batch_size=10 .......................
# [CV] ........ epochs=10, optimizer=Nadam, batch_size=10, total=   2.9s
# [CV] epochs=10, optimizer=Nadam, batch_size=10 .......................
# [CV] ........ epochs=10, optimizer=Nadam, batch_size=10, total=   3.1s
# [CV] epochs=10, optimizer=Nadam, batch_size=10 .......................
# [CV] ........ epochs=10, optimizer=Nadam, batch_size=10, total=   3.1s
# [CV] epochs=15, optimizer=SGD, batch_size=10 .........................
# [CV] .......... epochs=15, optimizer=SGD, batch_size=10, total=   3.2s
# [CV] epochs=15, optimizer=SGD, batch_size=10 .........................
# [CV] .......... epochs=15, optimizer=SGD, batch_size=10, total=   3.4s
# [CV] epochs=15, optimizer=SGD, batch_size=10 .........................
# [CV] .......... epochs=15, optimizer=SGD, batch_size=10, total=   3.3s
# [CV] epochs=15, optimizer=RMSprop, batch_size=10 .....................
# [CV] ...... epochs=15, optimizer=RMSprop, batch_size=10, total=   3.8s
# [CV] epochs=15, optimizer=RMSprop, batch_size=10 .....................
# [CV] ...... epochs=15, optimizer=RMSprop, batch_size=10, total=   3.2s
# [CV] epochs=15, optimizer=RMSprop, batch_size=10 .....................
# [CV] ...... epochs=15, optimizer=RMSprop, batch_size=10, total=   3.3s
# [CV] epochs=15, optimizer=Adagrad, batch_size=10 .....................
# [CV] ...... epochs=15, optimizer=Adagrad, batch_size=10, total=   3.2s
# [CV] epochs=15, optimizer=Adagrad, batch_size=10 .....................
# [CV] ...... epochs=15, optimizer=Adagrad, batch_size=10, total=   3.2s
# [CV] epochs=15, optimizer=Adagrad, batch_size=10 .....................
# [CV] ...... epochs=15, optimizer=Adagrad, batch_size=10, total=   3.3s
# [CV] epochs=15, optimizer=Adadelta, batch_size=10 ....................
# [CV] ..... epochs=15, optimizer=Adadelta, batch_size=10, total=   3.5s
# [CV] epochs=15, optimizer=Adadelta, batch_size=10 ....................
# [CV] ..... epochs=15, optimizer=Adadelta, batch_size=10, total=   3.5s
# [CV] epochs=15, optimizer=Adadelta, batch_size=10 ....................
# [CV] ..... epochs=15, optimizer=Adadelta, batch_size=10, total=   3.5s
# [CV] epochs=15, optimizer=Adam, batch_size=10 ........................
# [CV] ......... epochs=15, optimizer=Adam, batch_size=10, total=   3.6s
# [CV] epochs=15, optimizer=Adam, batch_size=10 ........................
# [CV] ......... epochs=15, optimizer=Adam, batch_size=10, total=   3.9s
# [CV] epochs=15, optimizer=Adam, batch_size=10 ........................
# [CV] ......... epochs=15, optimizer=Adam, batch_size=10, total=   3.7s
# [CV] epochs=15, optimizer=Adamax, batch_size=10 ......................
# [CV] ....... epochs=15, optimizer=Adamax, batch_size=10, total=   3.9s
# [CV] epochs=15, optimizer=Adamax, batch_size=10 ......................
# [CV] ....... epochs=15, optimizer=Adamax, batch_size=10, total=   3.9s
# [CV] epochs=15, optimizer=Adamax, batch_size=10 ......................
# [CV] ....... epochs=15, optimizer=Adamax, batch_size=10, total=   3.9s
# [CV] epochs=15, optimizer=Nadam, batch_size=10 .......................
# [CV] ........ epochs=15, optimizer=Nadam, batch_size=10, total=   4.1s
# [CV] epochs=15, optimizer=Nadam, batch_size=10 .......................
# [CV] ........ epochs=15, optimizer=Nadam, batch_size=10, total=   3.8s
# [CV] epochs=15, optimizer=Nadam, batch_size=10 .......................
# [CV] ........ epochs=15, optimizer=Nadam, batch_size=10, total=   3.8s
# [CV] epochs=5, optimizer=SGD, batch_size=20 ..........................
# [CV] ........... epochs=5, optimizer=SGD, batch_size=20, total=   2.4s
# [CV] epochs=5, optimizer=SGD, batch_size=20 ..........................
# [CV] ........... epochs=5, optimizer=SGD, batch_size=20, total=   2.4s
# [CV] epochs=5, optimizer=SGD, batch_size=20 ..........................
# [CV] ........... epochs=5, optimizer=SGD, batch_size=20, total=   2.6s
# [CV] epochs=5, optimizer=RMSprop, batch_size=20 ......................
# [CV] ....... epochs=5, optimizer=RMSprop, batch_size=20, total=   2.6s
# [CV] epochs=5, optimizer=RMSprop, batch_size=20 ......................
# [CV] ....... epochs=5, optimizer=RMSprop, batch_size=20, total=   2.6s
# [CV] epochs=5, optimizer=RMSprop, batch_size=20 ......................
# [CV] ....... epochs=5, optimizer=RMSprop, batch_size=20, total=   2.6s
# [CV] epochs=5, optimizer=Adagrad, batch_size=20 ......................
# [CV] ....... epochs=5, optimizer=Adagrad, batch_size=20, total=   2.6s
# [CV] epochs=5, optimizer=Adagrad, batch_size=20 ......................
# [CV] ....... epochs=5, optimizer=Adagrad, batch_size=20, total=   2.5s
# [CV] epochs=5, optimizer=Adagrad, batch_size=20 ......................
# [CV] ....... epochs=5, optimizer=Adagrad, batch_size=20, total=   2.6s
# [CV] epochs=5, optimizer=Adadelta, batch_size=20 .....................
# [CV] ...... epochs=5, optimizer=Adadelta, batch_size=20, total=   2.7s
# [CV] epochs=5, optimizer=Adadelta, batch_size=20 .....................
# [CV] ...... epochs=5, optimizer=Adadelta, batch_size=20, total=   3.1s
# [CV] epochs=5, optimizer=Adadelta, batch_size=20 .....................
# [CV] ...... epochs=5, optimizer=Adadelta, batch_size=20, total=   2.7s
# [CV] epochs=5, optimizer=Adam, batch_size=20 .........................
# [CV] .......... epochs=5, optimizer=Adam, batch_size=20, total=   2.7s
# [CV] epochs=5, optimizer=Adam, batch_size=20 .........................
# [CV] .......... epochs=5, optimizer=Adam, batch_size=20, total=   2.7s
# [CV] epochs=5, optimizer=Adam, batch_size=20 .........................
# [CV] .......... epochs=5, optimizer=Adam, batch_size=20, total=   2.7s
# [CV] epochs=5, optimizer=Adamax, batch_size=20 .......................
# [CV] ........ epochs=5, optimizer=Adamax, batch_size=20, total=   2.7s
# [CV] epochs=5, optimizer=Adamax, batch_size=20 .......................
# [CV] ........ epochs=5, optimizer=Adamax, batch_size=20, total=   2.8s
# [CV] epochs=5, optimizer=Adamax, batch_size=20 .......................
# [CV] ........ epochs=5, optimizer=Adamax, batch_size=20, total=   2.8s
# [CV] epochs=5, optimizer=Nadam, batch_size=20 ........................
# [CV] ......... epochs=5, optimizer=Nadam, batch_size=20, total=   2.8s
# [CV] epochs=5, optimizer=Nadam, batch_size=20 ........................
# [CV] ......... epochs=5, optimizer=Nadam, batch_size=20, total=   2.8s
# [CV] epochs=5, optimizer=Nadam, batch_size=20 ........................
# [CV] ......... epochs=5, optimizer=Nadam, batch_size=20, total=   2.8s
# [CV] epochs=10, optimizer=SGD, batch_size=20 .........................
# [CV] .......... epochs=10, optimizer=SGD, batch_size=20, total=   2.9s
# [CV] epochs=10, optimizer=SGD, batch_size=20 .........................
# [CV] .......... epochs=10, optimizer=SGD, batch_size=20, total=   2.9s
# [CV] epochs=10, optimizer=SGD, batch_size=20 .........................
# [CV] .......... epochs=10, optimizer=SGD, batch_size=20, total=   3.0s
# [CV] epochs=10, optimizer=RMSprop, batch_size=20 .....................
# [CV] ...... epochs=10, optimizer=RMSprop, batch_size=20, total=   3.2s
# [CV] epochs=10, optimizer=RMSprop, batch_size=20 .....................
# [CV] ...... epochs=10, optimizer=RMSprop, batch_size=20, total=   3.1s
# [CV] epochs=10, optimizer=RMSprop, batch_size=20 .....................
# [CV] ...... epochs=10, optimizer=RMSprop, batch_size=20, total=   3.1s
# [CV] epochs=10, optimizer=Adagrad, batch_size=20 .....................
# [CV] ...... epochs=10, optimizer=Adagrad, batch_size=20, total=   3.2s
# [CV] epochs=10, optimizer=Adagrad, batch_size=20 .....................
# [CV] ...... epochs=10, optimizer=Adagrad, batch_size=20, total=   3.1s
# [CV] epochs=10, optimizer=Adagrad, batch_size=20 .....................
# [CV] ...... epochs=10, optimizer=Adagrad, batch_size=20, total=   3.1s
# [CV] epochs=10, optimizer=Adadelta, batch_size=20 ....................
# [CV] ..... epochs=10, optimizer=Adadelta, batch_size=20, total=   3.2s
# [CV] epochs=10, optimizer=Adadelta, batch_size=20 ....................
# [CV] ..... epochs=10, optimizer=Adadelta, batch_size=20, total=   3.2s
# [CV] epochs=10, optimizer=Adadelta, batch_size=20 ....................
# [CV] ..... epochs=10, optimizer=Adadelta, batch_size=20, total=   3.2s
# [CV] epochs=10, optimizer=Adam, batch_size=20 ........................
# [CV] ......... epochs=10, optimizer=Adam, batch_size=20, total=   3.3s
# [CV] epochs=10, optimizer=Adam, batch_size=20 ........................
# [CV] ......... epochs=10, optimizer=Adam, batch_size=20, total=   3.3s
# [CV] epochs=10, optimizer=Adam, batch_size=20 ........................
# [CV] ......... epochs=10, optimizer=Adam, batch_size=20, total=   3.3s
# [CV] epochs=10, optimizer=Adamax, batch_size=20 ......................
# [CV] ....... epochs=10, optimizer=Adamax, batch_size=20, total=   3.4s
# [CV] epochs=10, optimizer=Adamax, batch_size=20 ......................
# [CV] ....... epochs=10, optimizer=Adamax, batch_size=20, total=   3.3s
# [CV] epochs=10, optimizer=Adamax, batch_size=20 ......................
# [CV] ....... epochs=10, optimizer=Adamax, batch_size=20, total=   3.5s
# [CV] epochs=10, optimizer=Nadam, batch_size=20 .......................
# [CV] ........ epochs=10, optimizer=Nadam, batch_size=20, total=   3.5s
# [CV] epochs=10, optimizer=Nadam, batch_size=20 .......................
# [CV] ........ epochs=10, optimizer=Nadam, batch_size=20, total=   3.5s
# [CV] epochs=10, optimizer=Nadam, batch_size=20 .......................
# [CV] ........ epochs=10, optimizer=Nadam, batch_size=20, total=   3.6s
# [CV] epochs=15, optimizer=SGD, batch_size=20 .........................
# [CV] .......... epochs=15, optimizer=SGD, batch_size=20, total=   3.7s
# [CV] epochs=15, optimizer=SGD, batch_size=20 .........................
# [CV] .......... epochs=15, optimizer=SGD, batch_size=20, total=   3.7s
# [CV] epochs=15, optimizer=SGD, batch_size=20 .........................
# [CV] .......... epochs=15, optimizer=SGD, batch_size=20, total=   4.2s
# [CV] epochs=15, optimizer=RMSprop, batch_size=20 .....................
# [CV] ...... epochs=15, optimizer=RMSprop, batch_size=20, total=   3.7s
# [CV] epochs=15, optimizer=RMSprop, batch_size=20 .....................
# [CV] ...... epochs=15, optimizer=RMSprop, batch_size=20, total=   3.9s
# [CV] epochs=15, optimizer=RMSprop, batch_size=20 .....................
# [CV] ...... epochs=15, optimizer=RMSprop, batch_size=20, total=   3.8s
# [CV] epochs=15, optimizer=Adagrad, batch_size=20 .....................
# [CV] ...... epochs=15, optimizer=Adagrad, batch_size=20, total=   3.7s
# [CV] epochs=15, optimizer=Adagrad, batch_size=20 .....................
# [CV] ...... epochs=15, optimizer=Adagrad, batch_size=20, total=   3.9s
# [CV] epochs=15, optimizer=Adagrad, batch_size=20 .....................
# [CV] ...... epochs=15, optimizer=Adagrad, batch_size=20, total=   3.7s
# [CV] epochs=15, optimizer=Adadelta, batch_size=20 ....................
# [CV] ..... epochs=15, optimizer=Adadelta, batch_size=20, total=   4.0s
# [CV] epochs=15, optimizer=Adadelta, batch_size=20 ....................
# [CV] ..... epochs=15, optimizer=Adadelta, batch_size=20, total=   3.9s
# [CV] epochs=15, optimizer=Adadelta, batch_size=20 ....................
# [CV] ..... epochs=15, optimizer=Adadelta, batch_size=20, total=   4.1s
# [CV] epochs=15, optimizer=Adam, batch_size=20 ........................
# [CV] ......... epochs=15, optimizer=Adam, batch_size=20, total=   4.1s
# [CV] epochs=15, optimizer=Adam, batch_size=20 ........................
# [CV] ......... epochs=15, optimizer=Adam, batch_size=20, total=   4.2s
# [CV] epochs=15, optimizer=Adam, batch_size=20 ........................
# [CV] ......... epochs=15, optimizer=Adam, batch_size=20, total=   4.1s
# [CV] epochs=15, optimizer=Adamax, batch_size=20 ......................
# [CV] ....... epochs=15, optimizer=Adamax, batch_size=20, total=   4.0s
# [CV] epochs=15, optimizer=Adamax, batch_size=20 ......................
# [CV] ....... epochs=15, optimizer=Adamax, batch_size=20, total=   4.0s
# [CV] epochs=15, optimizer=Adamax, batch_size=20 ......................
# [CV] ....... epochs=15, optimizer=Adamax, batch_size=20, total=   4.0s
# [CV] epochs=15, optimizer=Nadam, batch_size=20 .......................
# [CV] ........ epochs=15, optimizer=Nadam, batch_size=20, total=   4.1s
# [CV] epochs=15, optimizer=Nadam, batch_size=20 .......................
# [CV] ........ epochs=15, optimizer=Nadam, batch_size=20, total=   4.2s
# [CV] epochs=15, optimizer=Nadam, batch_size=20 .......................
# [CV] ........ epochs=15, optimizer=Nadam, batch_size=20, total=   4.2s
# [Parallel(n_jobs=1)]: Done 189 out of 189 | elapsed:  9.1min finished
# Best: 0.669271 using {'epochs': 15, 'optimizer': 'Nadam', 'batch_size': 20}
# 0.542969 (0.157321) with: {'epochs': 5, 'optimizer': 'SGD', 'batch_size': 5}
# 0.406250 (0.065907) with: {'epochs': 5, 'optimizer': 'RMSprop', 'batch_size': 5}
# 0.527344 (0.097003) with: {'epochs': 5, 'optimizer': 'Adagrad', 'batch_size': 5}
# 0.492188 (0.111082) with: {'epochs': 5, 'optimizer': 'Adadelta', 'batch_size': 5}
# 0.645833 (0.012890) with: {'epochs': 5, 'optimizer': 'Adam', 'batch_size': 5}
# 0.522135 (0.141251) with: {'epochs': 5, 'optimizer': 'Adamax', 'batch_size': 5}
# 0.656250 (0.025315) with: {'epochs': 5, 'optimizer': 'Nadam', 'batch_size': 5}
# 0.652344 (0.022999) with: {'epochs': 10, 'optimizer': 'SGD', 'batch_size': 5}
# 0.660156 (0.033603) with: {'epochs': 10, 'optimizer': 'RMSprop', 'batch_size': 5}
# 0.618490 (0.039879) with: {'epochs': 10, 'optimizer': 'Adagrad', 'batch_size': 5}
# 0.563802 (0.057262) with: {'epochs': 10, 'optimizer': 'Adadelta', 'batch_size': 5}
# 0.656250 (0.005524) with: {'epochs': 10, 'optimizer': 'Adam', 'batch_size': 5}
# 0.631510 (0.025780) with: {'epochs': 10, 'optimizer': 'Adamax', 'batch_size': 5}
# 0.527344 (0.143666) with: {'epochs': 10, 'optimizer': 'Nadam', 'batch_size': 5}
# 0.541667 (0.145263) with: {'epochs': 15, 'optimizer': 'SGD', 'batch_size': 5}
# 0.628906 (0.042910) with: {'epochs': 15, 'optimizer': 'RMSprop', 'batch_size': 5}
# 0.608073 (0.053019) with: {'epochs': 15, 'optimizer': 'Adagrad', 'batch_size': 5}
# 0.628906 (0.019401) with: {'epochs': 15, 'optimizer': 'Adadelta', 'batch_size': 5}
# 0.632813 (0.030425) with: {'epochs': 15, 'optimizer': 'Adam', 'batch_size': 5}
# 0.639323 (0.024150) with: {'epochs': 15, 'optimizer': 'Adamax', 'batch_size': 5}
# 0.580729 (0.112146) with: {'epochs': 15, 'optimizer': 'Nadam', 'batch_size': 5}
# 0.583333 (0.109065) with: {'epochs': 5, 'optimizer': 'SGD', 'batch_size': 10}
# 0.606771 (0.055823) with: {'epochs': 5, 'optimizer': 'RMSprop', 'batch_size': 10}
# 0.537760 (0.153137) with: {'epochs': 5, 'optimizer': 'Adagrad', 'batch_size': 10}
# 0.660156 (0.014616) with: {'epochs': 5, 'optimizer': 'Adadelta', 'batch_size': 10}
# 0.479167 (0.075228) with: {'epochs': 5, 'optimizer': 'Adam', 'batch_size': 10}
# 0.643229 (0.030647) with: {'epochs': 5, 'optimizer': 'Adamax', 'batch_size': 10}
# 0.528646 (0.100926) with: {'epochs': 5, 'optimizer': 'Nadam', 'batch_size': 10}
# 0.651042 (0.024774) with: {'epochs': 10, 'optimizer': 'SGD', 'batch_size': 10}
# 0.583333 (0.059868) with: {'epochs': 10, 'optimizer': 'RMSprop', 'batch_size': 10}
# 0.656250 (0.024910) with: {'epochs': 10, 'optimizer': 'Adagrad', 'batch_size': 10}
# 0.555990 (0.084525) with: {'epochs': 10, 'optimizer': 'Adadelta', 'batch_size': 10}
# 0.643229 (0.024360) with: {'epochs': 10, 'optimizer': 'Adam', 'batch_size': 10}
# 0.483073 (0.079757) with: {'epochs': 10, 'optimizer': 'Adamax', 'batch_size': 10}
# 0.645833 (0.020256) with: {'epochs': 10, 'optimizer': 'Nadam', 'batch_size': 10}
# 0.643229 (0.023939) with: {'epochs': 15, 'optimizer': 'SGD', 'batch_size': 10}
# 0.572917 (0.031948) with: {'epochs': 15, 'optimizer': 'RMSprop', 'batch_size': 10}
# 0.606771 (0.042112) with: {'epochs': 15, 'optimizer': 'Adagrad', 'batch_size': 10}
# 0.583333 (0.038051) with: {'epochs': 15, 'optimizer': 'Adadelta', 'batch_size': 10}
# 0.638021 (0.004872) with: {'epochs': 15, 'optimizer': 'Adam', 'batch_size': 10}
# 0.584635 (0.012890) with: {'epochs': 15, 'optimizer': 'Adamax', 'batch_size': 10}
# 0.652344 (0.015947) with: {'epochs': 15, 'optimizer': 'Nadam', 'batch_size': 10}
# 0.544271 (0.146518) with: {'epochs': 5, 'optimizer': 'SGD', 'batch_size': 20}
# 0.401042 (0.100472) with: {'epochs': 5, 'optimizer': 'RMSprop', 'batch_size': 20}
# 0.653646 (0.018136) with: {'epochs': 5, 'optimizer': 'Adagrad', 'batch_size': 20}
# 0.605469 (0.034499) with: {'epochs': 5, 'optimizer': 'Adadelta', 'batch_size': 20}
# 0.567708 (0.056005) with: {'epochs': 5, 'optimizer': 'Adam', 'batch_size': 20}
# 0.651042 (0.024774) with: {'epochs': 5, 'optimizer': 'Adamax', 'batch_size': 20}
# 0.584635 (0.023939) with: {'epochs': 5, 'optimizer': 'Nadam', 'batch_size': 20}
# 0.658854 (0.014382) with: {'epochs': 10, 'optimizer': 'SGD', 'batch_size': 20}
# 0.608073 (0.050865) with: {'epochs': 10, 'optimizer': 'RMSprop', 'batch_size': 20}
# 0.565104 (0.128939) with: {'epochs': 10, 'optimizer': 'Adagrad', 'batch_size': 20}
# 0.611979 (0.055457) with: {'epochs': 10, 'optimizer': 'Adadelta', 'batch_size': 20}
# 0.619792 (0.046475) with: {'epochs': 10, 'optimizer': 'Adam', 'batch_size': 20}
# 0.535156 (0.140444) with: {'epochs': 10, 'optimizer': 'Adamax', 'batch_size': 20}
# 0.669271 (0.017566) with: {'epochs': 10, 'optimizer': 'Nadam', 'batch_size': 20}
# 0.644531 (0.024910) with: {'epochs': 15, 'optimizer': 'SGD', 'batch_size': 20}
# 0.562500 (0.127218) with: {'epochs': 15, 'optimizer': 'RMSprop', 'batch_size': 20}
# 0.455729 (0.146518) with: {'epochs': 15, 'optimizer': 'Adagrad', 'batch_size': 20}
# 0.641927 (0.001841) with: {'epochs': 15, 'optimizer': 'Adadelta', 'batch_size': 20}
# 0.632813 (0.035943) with: {'epochs': 15, 'optimizer': 'Adam', 'batch_size': 20}
# 0.587240 (0.025582) with: {'epochs': 15, 'optimizer': 'Adamax', 'batch_size': 20}
# 0.669271 (0.023510) with: {'epochs': 15, 'optimizer': 'Nadam', 'batch_size': 20}
